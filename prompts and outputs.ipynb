# %% [markdown]
# ### Local llm
#
# first prompt:
#
#
#
# def build_prompt(data, flight, hotel, remain, dep_str, arr_str, nights, restaurants, warning=""):
#     prompt = f"""{warning}You are a helpful and professional travel planner.
#
# User details:
# Name: {data['name']}
# Travel route: {data['origin']} → {data['destination']}
# Departure date: {data['travel_date']}
# Return date: {data['return_date']} ({nights} nights)
# Budget: {data['budget']}
# Special needs: {data['special_needs']}
#
# Flight cost: {flight:.2f} AUD
# Departure: {dep_str}
# Arrival: {arr_str}
#
# Hotel cost for {nights} nights: {hotel:.2f} AUD
#
# Suggested restaurants:
# """
#     for r in restaurants:
#         prompt += f"- {r['name']} (Rating: {r['rating']}, Approx. {r['price']} AUD)\n  Address: {r['address']}\n"
#
#     prompt += f"\nRemaining budget: ~{remain:.2f} AUD\n\n"
#
#     prompt += (
#         "Now generate a realistic, structured itinerary broken into daily sections.\n\n"
#         "Use this format for each day:\n\n"
#         "Day X: [Short title for the day]\n\n"
#         "Time slots:\n"
#         "  - [HH:MM] - [Activity] (mention if free or approx. cost)\n\n"
#         "Meals:\n"
#         "  - Lunch: [Restaurant Name] (approx. cost)\n"
#         "  - Dinner: [Restaurant Name] (approx. cost)\n\n"
#         "Tips:\n"
#         "  - [Helpful daily travel tip, concise]\n\n"
#         "Only include activities that fit in one day realistically.\n"
#         "Do not repeat emojis, markdown symbols, or headers.\n"
#         "Keep the tone clean and practical.\n\n"
#         "At the end of the final day, write: END OF ITINERARY."
#     )
#     return prompt
#
#
#
# output: 11:30: Morning Food and Wine Tour (Approx. 100 AUD) 11:30 - 12:30: Lunch at NOMAD Melbourne (30 AUD) 12:00 - 13:30: Lunch at NOMAD Melbourne Dinner: Farmer's Daughters (45 AUD) 18:00 - 19:30: Dinner at Farmer's Daughters Tips: - Learn about the local food and wine scene during the tour. - Indulge in a variety of dishes and taste some excellent wines. Day 6: Shopping and Nightlife 09:00 - 11:30: Morning Shopping at Bourke Street (Free) 11:30 - 12:30: Lunch at Maha Restaurant (45 AUD) 12:00 - 13:30: Lunch at Maha Restaurant Dinner: NOMAD Melbourne (30 AUD) 18:00 - 19:30: Dinner at NOMAD Melbourne Tips: - Discover the vibrant shopping scene in Bourke Street. - Experience Melbourne's lively nightlife in the city center. Day 7: Day Trip to Philip Island 09:00 - 12:00: Day Trip to Philip Island (Approx. 250 AUD) 12:00 - 13:30: Lunch at NOMAD Melbourne (30 AUD) 12:00 - 13:30: Lunch at NOMAD Melbourne Dinner: Maha Restaurant (45 AUD) 18:00 - 19:30: Dinner at Maha Restaurant Tips: - Visit the famous Penguin Parade and see the little penguins up close. - Enjoy the breathtaking coastal scenery and wildlife on Philip Island. Day 8: Art and Culture 09:00 - 11:30: Visit the Australian Centre for the Moving Image (Free) 11:30 - 12:30: Lunch at NOMAD Melbourne (30 AUD) 12:00 - 13:30: Lunch at NOMAD Melbourne Dinner: Farmer's Daughters (45 AUD) 18:00 - 19:30: Dinner at Farmer's Daughters Tips: - Explore the history and future of Australian film and
#
# Type 'next' to continue.
#
# television at the ACMI. - Discover the work of local artists and designers at various galleries in the area. Day 9: Beach and City Tour 09:00 - 12:00: Visit St. Kilda Beach (Free) 12:00 - 13:30: Lunch at Maha Restaurant (45 AUD) 12:00 - 13:30: Lunch at Maha Restaurant Dinner: Farmer's Daughters (45 AUD) 18:00 - 19:30: Dinner at Farmer's Daughters Tips: - Return to St. Kilda Beach for one last day of relaxation. - Enjoy the evening in the city center before your departure. END OF ITINERARY.
#
# ✅ END OF ITINERARY.
#
#
#
# second prompt: def build_prompt(data, flight, hotel, remain, dep_str, arr_str, nights, restaurants, warning=""):
#     prompt = f"""{warning}You are an experienced travel planner. Your task is to create a clear, realistic, and structured itinerary for the user based on the details provided below.
#
# ## User Details:
# - Name: {data['name']}
# - Travel Route: {data['origin']} → {data['destination']}
# - Departure Date: {data['travel_date']}
# - Return Date: {data['return_date']} ({nights} nights)
# - Total Budget: {data['budget']}
# - Special Needs / Preferences: {data['special_needs']}
#
# ## Flight Information:
# - Flight Cost: {flight:.2f} AUD
# - Departure Time: {dep_str}
# - Arrival Time: {arr_str}
#
# ## Hotel Information:
# - Hotel Cost for {nights} nights: {hotel:.2f} AUD
#
# ## Recommended Restaurants:
# """
#     for r in restaurants:
#         prompt += f"- {r['name']} | Rating: {r['rating']} | Approx. {r['price']} AUD\n  Address: {r['address']}\n"
#
#     prompt += f"""
# ## Remaining Budget (after flight and hotel): ~{remain:.2f} AUD
#
# ---
#
# ## Itinerary Generation Instructions:
# 1. Plan the itinerary **day-by-day**.
# 2. Each day should be **balanced** with sightseeing, activities, rest periods, and meals.
# 3. Activities should include **time slots**, **location names**, and **estimated costs**.
# 4. Provide suggestions for **lunch** and **dinner**, using the recommended restaurants where appropriate.
# 5. Offer **one helpful tip per day** (e.g., cultural advice, weather warnings, travel tips).
# 6. Ensure no activity overlaps or unrealistic scheduling.
# 7. Respect the budget constraint as much as possible. If exceeded, mention where the plan can be optimized.
#
# ---
#
# ## Output Format:
# Day X: [Short title describing the day]
#
# Time Slots:
#   - [HH:MM] – [Activity / Location] (Estimated Cost or Free)
#
# Meals:
#   - Lunch: [Restaurant Name] (Approx. Cost)
#   - Dinner: [Restaurant Name] (Approx. Cost)
#
# Daily Tip:
#   - [One concise helpful tip]
#
# ---
#
# ✅ End the itinerary with the statement:
# "END OF ITINERARY."
# Do not include emojis, bullet symbols, or markdown styling.
#
# Provide the itinerary directly below.
# """
#     return prompt
#
#
# output: You are an experienced travel planner. Your task is to create a clear, realistic, and structured itinerary for the user based on the details provided below. ## User Details: - Name: reza - Travel Route: sydney → melbourne - Departure Date: 1 may 2025 - Return Date: 10 may 2025 (9 nights) - Total Budget: 6000 AUD - Special Needs / Preferences: no ## Flight Information: - Flight Cost: 1000.00 AUD - Departure Time: 01 May 2025 09:30 - Arrival Time: 02 May 2025 02:30 ## Hotel Information: - Hotel Cost for 9 nights: 3600.00 AUD ## Recommended Restaurants: - Farmer's Daughters | Rating: 4.5 | Approx. 45 AUD Address: 95 Exhibition Street, 80 Collins Precinct, Melbourne VIC 3000, Austral
:00 – Lunch at Farmer's Daughters (Approx. 45 AUD) - 14:00 – Visit the Royal Melbourne Golf Club (Estimated Cost: 20 AUD) - 16:00 – Explore the Fitzroy Gardens (Free) - 18:00 – Dinner at NOMAD Melbourne (Approx. 30 AUD) Meals: - Lunch: Farmer's Daughters (Approx. 45 AUD) - Dinner: NOMAD Melbourne (Approx. 30 AUD) Daily Tip: - Don't miss the street art in Fitzroy Gardens. --- Day 7: Melbourne Activities Time Slots: - 10:00 – Walk or cycle around the Yarra River (Free) - 12:00 –
#
# Type 'next' to continue.
#
# Lunch at Maha Restaurant (Approx. 45 AUD) - 14:00 – Visit the Melbourne Park (Estimated Cost: 25 AUD) - 16:00 – Explore the Queen Victoria Market (Free) - 18:00 – Dinner at Maha Restaurant (Approx. 45 AUD) Meals: - Lunch: Maha Restaurant (Approx. 45 AUD) - Dinner: Maha Restaurant (Approx. 45 AUD) Daily Tip: - Make sure to try some local produce at the Queen Victoria Market. --- Day 8: Melbourne Rest Day Time Slots: - None Meals: - Lunch: None (Reza can grab something quick from a nearby cafe) - Dinner: N/A (Reza will eat on the plane) Daily Tip: - Take this day to relax and explore the city at your own pace. --- Day 9: Melbourne Departure Time Slots: - 10:00 – Check-out from hotel and head to the airport (Free) Meals: - Lunch: None (Reza will eat on the plane) - Dinner: N/A (Reza will eat on the plane) Daily Tip: - Double-check your flight times and make sure you have all necessary documents. --- Day 10: Return to Sydney Time Slots: - 14:00 – Arrive Sydney (Free) Meals: - Lunch: None (Reza will eat on the plane) - Dinner: N/A (Reza will eat on the plane) Daily Tip: - Enjoy your last night in Sydney before heading back home. --- END OF ITINERARY.
#
# ✅ END OF ITINERARY.
#
#
#
# third prompt: def build_prompt(data, flight, hotel, remain, dep_str, arr_str, nights, restaurants, warning=""):
#     prompt = f"""{warning}
#
# Itinerary Details:
# - Name: {data['name']}
# - Route: {data['origin']} → {data['destination']}
# - Departure: {data['travel_date']} at {dep_str}
# - Return: {data['return_date']} at {arr_str} ({nights} nights)
# - Budget: {data['budget']} (Remaining after flight and hotel: ~{remain:.2f} AUD)
# - Special Needs / Preferences: {data['special_needs']}
#
# Flight Cost: {flight:.2f} AUD
# Hotel Cost for {nights} nights: {hotel:.2f} AUD
#
# Recommended Restaurants:
# """
#     for r in restaurants:
#         prompt += f"- {r['name']} | Rating: {r['rating']} | Approx. {r['price']} AUD\n  Address: {r['address']}\n"
#
#     prompt += f"""
#
# ======================
# Please generate a structured day-by-day itinerary. Use the following rules:
#
# 1. Write each day as: **Day X: [Short title describing the day]**
# 2. Under each day, use the following format:
#    Time Slots:
#      - [HH:MM] – [Activity / Location] (Estimated Cost or Free)
#    Meals:
#      - Lunch: [Restaurant Name] (Approx. Cost)
#      - Dinner: [Restaurant Name] (Approx. Cost)
#    Daily Tip:
#      - [Helpful advice for the day]
#
# 3. Do NOT start with any extra introductory sentences.
# 4. Do NOT use emojis, markdown, or bullet symbols (just clean text).
# 5. If the plan exceeds the budget, mention which parts could be optimised.
# 6. Ensure daily balance: sightseeing, activities, meals, and rest periods.
# 7. Respect realistic travel time between locations.
# 8. End the itinerary with this sentence exactly:
# END OF ITINERARY.
# """
#     return prompt
#
#
#
# output: Itinerary Details: - Name: reza - Route: sydney → melbourne - Departure: 1 may 2025 at 01 May 2025 09:30 - Return: 10 may 2025 at 02 May 2025 02:30 (9 nights) - Budget: 6000 AUD (Remaining after flight and hotel: ~1400.00 AUD) - Special Needs / Preferences: no Flight Cost: 1000.00 AUD Hotel Cost for 9 nights: 3600.00 AUD Recommended Restaurants: - Farmer's Daughters | Rating: 4.5 | Approx. 45 AUD Address: 95 Exhibition Street, 80 Collins Precinct, Melbourne VIC 3000, Australia - Maha Restaurant | Rating: 4.5 | Approx. 45 AUD Address: 21 Bond St, Melbourne VIC 3000, Australia - NOMAD Melbourne | Rating: 4.5 | Approx. 30 AUD Address: 187 Flinders Ln, Melbourne VIC 3000, Australia ====================== Please generate a structured day-by-day itinerary. Use the following rules: 1. Write each day as: Day X: [Short title describing the day] 2. Under each day, use the following format: Time Slots: - [HH:MM] – [Activity / Location] (Estimated Cost or Free) Meals: - Lunch: [Restaurant Name] (Approx. Cost) - Dinner: [Restaurant Name] (Approx. Cost) Daily Tip: - [Helpful advice for the day] 3. Do NOT start with any extra introductory sentences. 4. Do NOT use emojis, markdown, or bullet symbols (just clean text). 5. If the plan exceeds the budget, mention which parts could be optimised. 6. Ensure daily balance: sightseeing, activities, meals, and rest periods. 7. Respect realistic travel time between locations. 8. End the itinerary with this sentence exactly: END OF ITINERARY. ====================== Day 1: Sydney Time
#
# Type 'next' to continue.
#
# Slots: - 09:30 – Arrive Sydney (Free) - 10:00 – Visit Sydney Opera House (Free admission) - 12:00 – Lunch at Farmer's Daughters (Approx. 45 AUD) - 13:30 – Explore Royal Botanic Garden (Free admission) - 16:00 – Relax at Bondi Beach (Free) - 18:30 – Dinner at Maha Restaurant (Approx. 45 AUD) - 21:00 – Return to hotel Meals: - Lunch: Farmer's Daughters (Approx. 45 AUD) - Dinner: Maha Restaurant (Approx. 45 AUD) Daily Tip: - Wear comfortable shoes for exploring the city and beach. ====================== Day 2: Sydney Time Slots: - 09:00 – Breakfast at Bread & Butter Project (Approx. 30 AUD) - 10:30 – Visit Taronga Zoo (Approx. 65 AUD) - 14:00 – Lunch at NOMAD Melbourne (Approx. 30 AUD) - 15:30 – Explore Barangaroo Reserve (Free admission) - 18:00 – Dinner at Sepia (Approx. 65 AUD) - 21:00 – Return to hotel Meals: - Breakfast: Bread & Butter Project (Approx. 30 AUD) - Lunch: NOMAD Melbourne (Approx. 30 AUD) - Dinner: Sepia (Approx. 65 AUD) Daily Tip: - Bring reusable water bottles to save money on drinks. ====================== Day 3: Melbourne Time Slots: - 08:00 – Arrive Melbourne (Approx. 120 AUD) - 09:30 – Check into hotel and freshen up - 11:00 – Visit Federation Square (Free admission) - 13:00 – Lunch at Farmer's Daughters (Approx. 45 AUD) - 14:30 – Explore Melbourne Street Art (Free) - 17:00 – Relax at Fitzroy Gardens (Free admission) - 19:30 – Dinner at NOMAD Melbourne (Approx. 30 AUD) -
#
# Type 'next' to continue.
#
# 19:30 – Dinner at NOMAD Melbourne (Approx. 30 AUD) - 22:00 – Return to hotel Meals: - Breakfast: Seven Seeds (Approx. 35 AUD) - Lunch: NOMAD Melbourne (Approx. 30 AUD) - Dinner: NOMAD Melbourne (Approx. 30 AUD) Daily Tip: - Wear comfortable shoes for exploring Flinders Street and Carlton. ====================== Day 9: Melbourne Time Slots: - 09:00 – Breakfast at Cumulus Inc. (Approx. 30 AUD) - 10:30 – Visit the National Gallery of Victoria (Approx. 25 AUD) - 13:00 – Lunch at NOMAD Melbourne (Approx. 30 AUD) - 14:30 – Explore Fitzroy (Free)
#
# ✅ END OF ITINERARY.
#
#
# fourth prompt:def build_prompt_json(data, flight, hotel, remain, dep_str, arr_str, nights, restaurants, warning=""):
#     prompt = f"""{warning}
#
# Create the travel itinerary as a valid JSON object.
#
# The JSON should have:
# - A top-level "itinerary" list, each item is a day.
# - Each "day" object must contain:
#   - "day_number": integer (e.g., 1, 2, 3, ...)
#   - "title": short description of the day
#   - "time_slots": list of {{"time": "HH:MM", "activity": "activity description", "cost": "estimated cost or 'Free'"}}
#   - "meals": object with keys "breakfast", "lunch", "dinner", each value being a restaurant name and approximate cost (if any)
#   - "daily_tip": string (helpful advice for the day)
#
# Additional fields (only once at the start of the JSON):
# - "user_details": {{
#     "name": "{data['name']}",
#     "route": "{data['origin']} → {data['destination']}",
#     "departure": "{data['travel_date']} at {dep_str}",
#     "return": "{data['return_date']} at {arr_str}",
#     "nights": {nights},
#     "budget": "{data['budget']}",
#     "remaining_budget": "{remain:.2f} AUD",
#     "special_needs": "{data['special_needs']}"
#   }}
# - "flight": {{
#     "cost": "{flight:.2f} AUD",
#     "departure_time": "{dep_str}",
#     "arrival_time": "{arr_str}"
#   }}
# - "hotel": {{
#     "cost": "{hotel:.2f} AUD",
#     "nights": {nights}
#   }}
# - "recommended_restaurants": [
# """
#     for r in restaurants:
#         prompt += f"""    {{
#         "name": "{r['name']}",
#         "rating": "{r['rating']}",
#         "approx_price": "{r['price']} AUD",
#         "address": "{r['address']}"
#     }},"""
#     prompt = prompt.rstrip(",")  # Remove the last comma
#     prompt += """
# ]
#
# Rules for generation:
# 1. Do not include any introductory text before or after the JSON.
# 2. Ensure the JSON is complete and properly formatted.
# 3. Respect realistic scheduling between activities and meals.
# 4. Mention "remaining budget" at the end of each day if possible.
# 5. If the plan exceeds the budget, include a "budget_warning" field explaining which parts may be optimized.
# 6. End with a closing curly brace for the JSON object.
#
# Output only the JSON object.
# """
#     return prompt
#
#
#
# output: Create the travel itinerary as a valid JSON object. The JSON should have: - A top-level "itinerary" list, each item is a day. - Each "day" object must contain: - "day_number": integer (e.g., 1, 2, 3, ...) - "title": short description of the day - "time_slots": list of {"time": "HH:MM", "activity": "activity description", "cost": "estimated cost or 'Free'"} - "meals": object with keys "breakfast", "lunch", "dinner", each value being a restaurant name and approximate cost (if any) - "daily_tip": string (helpful advice for the day) Additional fields (only once at the start of the JSON): - "user_details": { "name": "reza", "route": "sydney → melbourne", "departure": "1 may 2025 at 01 May 2025 09:30", "return": "10 may 2025 at 02 May 2025 02:30", "nights": 9, "budget": "6000 AUD", "remaining_budget": "1400.00 AUD", "special_needs": "no" } - "flight": { "cost": "1000.00 AUD", "departure_time": "01 May 2025 09:30", "arrival_time": "02 May 2025 02:30" } - "hotel": { "cost": "3600.00 AUD", "nights": 9 } - "recommended_restaurants": [ { "name": "Farmer's Daughters", "rating": "4.5", "approx_price": "45 AUD", "address": "95 Exhibition Street, 80 Collins Precinct, Melbourne VIC 3000, Australia" }, { "name": "Maha Restaurant", "rating": "4.5", "approx_price": "45 AUD", "address": "21 Bond St, Melbourne VIC 3000, Australia" }, { "name": "NOMAD Melbourne", "rating": "4.5", "approx_price": "30 AUD", "address": "187 Flinders Ln, Melbourne VIC 3000, Australia" } ] Rules for generation: 1. Do not include any introductory text before or after the JSON. 2. Ensure the JSON is complete and properly formatted. 3. Respect realistic scheduling between activities
#
# Type 'next' to continue.
#
#
#
# and meals. 4. Mention "remaining budget" at the end of each day if possible. 5. If the plan exceeds the budget, include a "budget_warning" field explaining which parts may be optimized. 6. End with a closing curly brace for the JSON object. Output only the JSON object. Note: - The example is for Melbourne to Sydney travel. Adjust accordingly for other routes. - The example assumes the traveler is a food lover and can afford moderate priced restaurants. Adjust accordingly for other types of travelers and budgets. Example Output: ```json { "itinerary": [ { "day_number": 1, "title": "Arrive in Melbourne", "time_slots": [ { "time": "09:30", "activity": "Arrive at Tullamarra Airport", "cost": "Free" } ], "meals": { "breakfast": "Farmer's Daughters", "lunch": "Maha Restaurant", "dinner": "NOMAD Melbourne", "daily_tip": "Welcome to Melbourne!" }, "remaining_budget": "5400.00 AUD" }, { "day_number": 2, "title": "Explore Melbourne", "time_slots": [ { "time": "10:00", "activity": "Visit the National Gallery of Victoria", "cost": "Free" }, { "time": "12:00", "activity": "Lunch at Farmer's Daughters", "cost": "45.00 AUD" }, { "time": "13:30", "activity": "Take a walking tour of Melbourne", "cost": "40.00 AUD" }, { "time": "16:00", "activity": "Visit the Queen Victoria Market", "cost": "Free" }, { "time": "18:30", "activity": "Dinner at NOMAD Melbourne", "cost": "30.00 AUD" } ], "meals": { "breakfast": "Farmer's Daughters", "lunch": "Farmer's Daughters", "dinner": "NOMAD Melbourne", "daily_tip": "Enjoy the art and culture of Melbourne!" }, "remaining_budget": "2370.00 AUD" }, { "day_number": 3, "title": "Day trip to Phillip Island", "time_slots": [ { "time": "08:30", "activity": "Depart from Melbourne", "cost": "200.00
#
# Type 'next' to continue.
#
# AUD" }, { "time": "10:30", "activity": "Arrive at Phillip Island", "cost": "Free" }, { "time": "12:00", "activity": "Lunch at The Islander", "cost": "35.00 AUD" }, { "time": "14:00", "activity": "Watch the penguins at the colony", "cost": "25.00 AUD" }, { "time": "16:00", "activity": "Visit the Cape Paterson Lighthouse", "cost": "Free" }, { "time": "18:00", "activity": "Depart from Phillip Island", "cost": "200.00 AUD" } ], "meals": { "breakfast": "Farmer's Daughters", "lunch": "The Islander", "dinner": "NOMAD Melbourne", "daily_tip": "Take a day trip to see the famous penguins!" }, "remaining_budget": "1170.00 AUD" }, { "day_number": 4, "title": "Explore Great Ocean Road", "time_slots": [ { "time": "08:30", "activity": "Depart from Melbourne", "cost": "200.00 AUD" }, { "time": "10:30", "activity": "Arrive at Great Ocean Road", "cost": "Free" }, { "time": "12:00", "activity": "Lunch at 12 Apostles Roadhouse", "cost": "35.00 AUD" }, { "time": "14:00", "activity": "Visit the 12 Apostles", "cost": "Free" }, { "time": "16:00", "activity": "Visit the Great Otway National Park", "cost": "Free" }, { "time": "18:00", "activity": "Depart from Great Ocean Road", "cost": "200.00 AUD" } ], "meals": { "breakfast": "Farmer's Daughters", "lunch": "12 Apostles Roadhouse", "dinner": "NOMAD Melbourne", "daily_tip": "Experience the breathtaking views of the Great Ocean Road!" }, "remaining_budget": "1170.00 AUD" }, { "day_number": 5, "title": "Relax in the Yarra Valley", "time_slots": [ { "time": "08:30", "activity": "Depart from Melbourne", "cost": "150.00 AUD" }, { "time": "10:30", "activity": "Arrive in the Yarra Valley", "cost": "Free" }, { "time": "12:00", "activity": "Lunch at The Yarra Valley Bakery", "cost": "25.00 AUD" }, {
#
# Type 'next' to continue.
#
# "time": "14:00", "activity": "Wine tasting at Yering Station", "cost": "50.00 AUD" }, { "time": "16:00", "activity": "Relax at the spa", "cost": "150.00 AUD" }, { "time": "18:00", "activity": "Dinner at The Yarra Valley Restaurant", "cost": "30.00 AUD" } ], "meals": { "breakfast": "Farmer's Daughters", "lunch": "The Yarra Valley Bakery", "dinner": "The Yarra Valley Restaurant", "daily_tip": "Indulge in a relaxing day in the Yarra Valley!" }, "remaining_budget": "1570.00 AUD" }, { "day_number": 6, "title": "Sydney bound", "time_slots": [ { "time": "08:30", "activity": "Depart from Melbourne", "cost": "250.00 AUD" }, { "time": "10:30", "activity": "Arrive in Sydney", "cost": "Free" }, { "time": "12:00", "activity": "Lunch at Sepia", "cost": "45.00 AUD" }, { "time": "13:30", "activity": "Visit the Art Gallery of New South Wales", "cost": "Free" }, { "time": "16:00", "activity": "Relax at the beach", "cost": "Free" }, { "time": "18:30", "activity":
#
# ✅ END OF ITINERARY.
#
#
# fifth prompt:
#
# def build_prompt(data, flight, hotel, remain, dep_str, arr_str, nights, restaurants, warning=""):
#     # Construct the recommended restaurants list:
#     restaurant_info = "\n".join(
#         [f"- {r['name']} | Rating: {r['rating']} | Approx. {r['price']} AUD\n  Address: {r['address']}" for r in restaurants]
#     )
#
#     # Build the full prompt:
#     prompt = f"""{warning}Please generate a structured, day-by-day travel itinerary based on the following user details:
#
# User Details:
# - Name: {data['name']}
# - Route: {data['origin']} → {data['destination']}
# - Departure: {data['travel_date']} at {dep_str}
# - Return: {data['return_date']} at {arr_str} ({nights} nights)
# - Budget: {data['budget']} AUD (Remaining after flight and hotel: ~{remain:.2f} AUD)
# - Special Needs / Preferences: {data['special_needs']}
#
# Flight Cost: {flight:.2f} AUD
# Hotel Cost for {nights} nights: {hotel:.2f} AUD
#
# Recommended Restaurants:
# {restaurant_info}
#
# ============================
#
# Itinerary Generation Rules:
# 1. Write each day as: Day X: [Short title describing the day].
# 2. Strictly follow this output structure under each day:
#
# Day X: [Short title]
#
# Time Slots:
# [HH:MM] – [Activity / Location] (Estimated Cost or Free)
# [HH:MM] – [Activity / Location] (Estimated Cost or Free)
# [HH:MM] – [Activity / Location] (Estimated Cost or Free)
#
# Meals:
# Lunch: [Restaurant Name] (Approx. Cost)
# Dinner: [Restaurant Name] (Approx. Cost)
#
# Daily Tip:
# [One concise helpful tip]
#
# 3. Each activity must appear on a **new line**.
# 4. Leave **one blank line between each day**.
# 5. Do **NOT** include markdown, emojis, bullet points, or extra explanatory text.
# 6. Avoid repeating the same restaurant too often unless necessary.
# 7. If the plan exceeds the budget, mention where the budget can be optimised.
# 8. Ensure daily balance: sightseeing, rest periods, meals, and realistic travel times between locations.
# 9. End the itinerary with this exact sentence:
# END OF ITINERARY.
#
# ============================
#
# Please directly output the itinerary below following these rules.
# """
#     return prompt
#
#
#
#
# output:
# Please generate a structured, day-by-day travel itinerary based on the following user details: User Details: - Name: reza - Route: sydney → melbourne - Departure: 1 may 2025 at 01 May 2025 09:30 - Return: 10 may 2025 at 02 May 2025 02:30 (9 nights) - Budget: 6000 AUD AUD (Remaining after flight and hotel: ~1400.00 AUD) - Special Needs / Preferences: no Flight Cost: 1000.00 AUD Hotel Cost for 9 nights: 3600.00 AUD Recommended Restaurants: - Farmer's Daughters | Rating: 4.5 | Approx. 45 AUD Address: 95 Exhibition Street, 80 Collins Precinct, Melbourne VIC 3000, Australia - Maha Restaurant | Rating: 4.5 | Approx. 45 AUD Address: 21 Bond St, Melbourne VIC 3000, Australia - NOMAD Melbourne | Rating: 4.5 | Approx. 30 AUD Address: 187 Flinders Ln, Melbourne VIC 3000, Australia ============================ Itinerary Generation Rules: 1. Write each day as: Day X: [Short title describing the day]. 2. Strictly follow this output structure under each day: Day X: [Short title] Time Slots: [HH:MM] – [Activity / Location] (Estimated Cost or Free) [HH:MM] – [Activity / Location] (Estimated Cost or Free) [HH:MM] – [Activity / Location] (Estimated Cost or Free) Meals: Lunch: [Restaurant Name] (Approx. Cost) Dinner: [Restaurant Name] (Approx. Cost) Daily Tip: [One concise helpful tip] 3. Each activity must appear on a new line. 4. Leave one blank line between each day. 5. Do NOT include markdown, emojis, bullet points, or extra explanatory text. 6. Avoid repeating the same restaurant too often unless necessary. 7. If the
#
# Type 'next' to continue.
#
# plan exceeds the budget, mention where the budget can be optimised. 8. Ensure daily balance: sightseeing, rest periods, meals, and realistic travel times between locations. 9. End the itinerary with this exact sentence: END OF ITINERARY. ============================ Please directly output the itinerary below following these rules. Day 1: Arrival Time Slots: 09:30 – Arrival in Sydney (Free) 10:00 – Flight from Sydney to Melbourne (1000.00 AUD) 11:00 – Check-in at hotel in Melbourne (3600.00 AUD) Meals: Lunch: N/A Dinner: N/A Daily Tip: Arr
library of Victoria (Free) - 15:00 – Relax at a laneway cafe (Approx. 15 AUD) Meals: - Lunch: Casual laneway cafe (Approx. 20 AUD) - Dinner: Farmer's Daughters (Approx. 45 AUD) Daily Tip: - Get lost in the laneways and discover hidden gems. Day 6: Museums and Art Time Slots: - 09:00 – Visit the Melbourne Museum (Approx. 20 AUD) - 11:00 – Explore the Ian Potter Centre: NGV Australia (Free entry to permanent collections) - 13:00 – Lunch at a cafe in Federation Square (Approx. 20 AUD) - 14:00 – ACMI – Australian Centre for the Moving Image (Free entry to some exhibitions) Meals: - Lunch: Cafe in Federation Square (Approx. 20 AUD) - Dinner: Dinner at a restaurant of your choice (Approx. 35 AUD) Daily Tip: - Check for special exhibitions at the museums. Day 7: Shopping and Relaxation Time Slots: - 10:00 – Shopping at Bourke Street Mall
#
# Type 'next' to continue.
#
# (Free) - 12:00 – Lunch at a cafe in Bourke Street Mall (Approx. 20 AUD) - 14:00 – Relax at Fitzroy Gardens (Free) - 16:00 – Visit Captain Cook's Cottage (Approx. 10 AUD) Meals: - Lunch: Cafe in Bourke Street Mall (Approx. 20 AUD) - Dinner: Restaurant of your choice (Approx. 35 AUD) Daily Tip: - Take a break from the city buzz and enjoy the tranquility of Fitzroy Gardens. Day 8: Yarra River and Southbank Time Slots: - 09:00 – Walk along the Yarra River (Free) - 11:00 – Visit the Eureka Skydeck (Approx. 25 AUD) - 13:00 – Explore Southbank Promenade (Free) - 15:00 – Crown Casino Complex (Free to enter) Meals: - Lunch: Casual dining at Southbank (Approx. 20 AUD) - Dinner: Restaurant at Southbank (Approx. 40 AUD) Daily Tip: - Enjoy the city views from the Eureka Skydeck. Day 9: Departure Time Slots: - 09:00 – Enjoy a final Melbourne breakfast (Approx. 20 AUD) - 10:00 – Last-minute souvenir shopping (Optional) - 12:00 – Check out of hotel (Free) - 13:00 – Transfer to Melbourne Airport (Approx. 20 AUD) - 15:00 - Depart Melbourne (Free) Meals: - Lunch: Airport food (Approx. 20 AUD) - Dinner: N/A Daily Tip: - Allow ample time for airport transfer. If the optional Great Ocean Road trip is taken, the total cost will exceed the budget. This could be optimised by choosing less expensive dining options on other days or by skipping some paid attractions. END OF ITINERARY.
#
# ✅ END OF ITINERARY.
#
#
# fourth prompt output:
#
# { "user_details": { "name": "reza", "route": "sydney → melbourne", "departure": "1 May 2025 at 01 May 2025 09:30", "return": "10 May 2025 at 02 May 2025 02:30", "nights": 9, "budget": "6000 AUD", "remaining_budget": "1400.00 AUD", "special_needs": "no" }, "flight": { "cost": "1000.00 AUD", "departure_time": "01 May 2025 09:30", "arrival_time": "02 May 2025 02:30" }, "hotel": { "cost": "3600.00 AUD", "nights": 9 }, "recommended_restaurants": [ { "name": "Farmer's Daughters", "rating": "4.5", "approx_price": "45 AUD", "address": "95 Exhibition Street, 80 Collins Precinct, Melbourne VIC 3000, Australia" }, { "name": "Maha Restaurant", "rating": "4.5", "approx_price": "45 AUD", "address": "21 Bond St, Melbourne VIC 3000, Australia" }, { "name": "NOMAD Melbourne", "rating": "4.5", "approx_price": "30 AUD", "address": "187 Flinders Ln, Melbourne VIC 3000, Australia" } ], "itinerary": [ { "day_number": 1, "title": "Arrival and City Exploration", "time_slots": [ {"time": "14:00", "activity": "Check in to hotel", "cost": "Free"}, {"time": "15:00", "activity": "Explore Federation Square", "cost": "Free"}, {"time": "17:00", "activity": "Visit St Paul's Cathedral", "cost": "Free"} ], "meals": { "breakfast": "N/A", "lunch": "Cafe at Federation Square (Approx. 20 AUD)", "dinner": "NOMAD Melbourne (Approx. 30 AUD)" }, "daily_tip": "Wear comfortable shoes for walking.", "remaining_budget": "1350.00 AUD" }, { "day_number": 2, "title": "Melbourne's Laneway Culture", "time_slots": [ {"time": "10:00", "activity": "Explore Hosier Lane's street art", "cost": "Free"}, {"time": "12:00", "activity": "Lunch at a laneway cafe", "cost": "25 AUD"}, {"time": "14:00", "activity": "Shopping at Queen Victoria Market", "cost": "50 AUD (Souvenirs)"} ], "meals": { "breakfast": "Hotel Breakfast (Included)", "lunch": "Laneway Cafe (Approx. 25 AUD)", "dinner": "Maha Restaurant (Approx. 45
#
# Type 'next' to continue.
#
# AUD)" }, "daily_tip": "Bring your camera to capture the vibrant street art.", "remaining_budget": "1230.00 AUD" }, { "day_number": 3, "title": "Royal Botanic Gardens and Shrine of Remembrance", "time_slots": [ {"time": "10:00", "activity": "Visit the Royal Botanic Gardens", "cost": "Free"}, {"time": "13:00", "activity": "Picnic lunch in the gardens", "cost": "20 AUD"}, {"time": "15:00", "activity": "Pay respects at the Shrine of Remembrance", "cost": "Free"} ], "meals": { "breakfast": "Hotel Breakfast (Included)", "lunch": "Picnic Lunch (Approx. 20 AUD)", "dinner": "Farmer's Daughters (Approx. 45 AUD)" }, "daily_tip": "Enjoy the serene atmosphere of the gardens.", "remaining_budget": "1165.00 AUD" } ], "budget_warning": "Your current itinerary is within your remaining budget. However, days 4-9 are not planned and you only have 1165.00 AUD remaining. Consider adding more free activities or less expensive dining options to stay within budget." }
#
# ✅ END OF ITINERARY.
#
#
# fifth prompt output:
#
# Day 1: Arrival in Melbourne Time Slots: 09:30 – Arrive at Melbourne Airport (Free) 10:30 – Transfer to Hotel (Taxi/Skybus - Approx. 25 AUD) 11:30 – Check in to Hotel (Free) 12:30 – Lunch near Hotel (Approx. 20 AUD) 14:00 – Explore Federation Square (Free) 16:00 – Visit Flinders Street Station (Free) 17:00 – Relax at hotel (Free) Meals: Lunch: Cafe near Hotel (Approx. 20 AUD) Dinner: NOMAD Melbourne (Approx. 30 AUD) Daily Tip: Purchase a Myki card for easy travel on public transport. Day 2: Melbourne's Cultural Heart Time Slots: 09:00 – Visit the State Library of Victoria (Free) 11:00 – Explore Melbourne Museum (Approx. 20 AUD) 13:00 – Lunch at a cafe in Carlton (Approx. 20 AUD) 14:30 – Wander through the Royal Botanic Gardens (Free) 17:00 – Return to hotel and relax (Free) Meals: Lunch: Cafe in Carlton (Approx. 20 AUD) Dinner: Maha Restaurant (Approx. 45 AUD) Daily Tip: Check for free guided tours at the Royal Botanic Gardens. Day 3: